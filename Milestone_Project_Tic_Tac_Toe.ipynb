# %% [markdown]
# ___
#
# <a href='https://www.udemy.com/user/joseportilla/'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Content Copyright by Pierian Data</em></center>

# %% [markdown]
# # Milestone Project 1
# ## Congratulations on making it to your first milestone!
# You've already learned a ton and are ready to work on a real project.
#
# Your assignment: Create a Tic Tac Toe game. You are free to use any IDE you like.
#
# Here are the requirements:
#
# * 2 players should be able to play the game (both sitting at the same computer)
# * The board should be printed out every time a player makes a move
# * You should be able to accept input of the player position and then place a symbol on the board
#
# Feel free to use Google or any chatbot to help you figure anything out (but don't just ask "Tic Tac Toe in Python" otherwise you won't learn anything!) Keep in mind that this project can take anywhere between several hours to several days.
#
# There are 4 Jupyter Notebooks related to this assignment:
#
# * This Assignment Notebook
# * A "Walkthrough Steps Workbook" Notebook
# * A "Complete Walkthrough Solution" Notebook
# * An "Advanced Solution" Notebook
#
# I encourage you to just try to start the project on your own without referencing any of the notebooks. If you get stuck, check out the next lecture which is a text lecture with helpful hints and steps. If you're still stuck after that, then check out the Walkthrough Steps Workbook, which breaks up the project in steps for you to solve. Still stuck? Then check out the Complete Walkthrough Solution video for more help on approaching the project!

# %% [markdown]
# There are parts of this that will be a struggle...and that is good! I have complete faith that if you have made it this far through the course you have all the tools and knowledge to tackle this project. Remember, it's totally open book, so take your time, do a little research, and remember:
#
# ## HAVE FUN!

# %%
def display_board(board):
    # Using f-strings just like you did, but mapped to a single list
    print(f" {board[7]} | {board[8]} | {board[9]} ")
    print("-----------")
    print(f" {board[4]} | {board[5]} | {board[6]} ")
    print("-----------")
    print(f" {board[1]} | {board[2]} | {board[3]} ")

# %%
def user_choice():
    choice='Wrong'
    acceptable_range= range(1,10)
    within_range=False
    while choice.isdigit()==False or within_range==False:
        choice=input(f"Enter number from 1-9:")
        if choice.isdigit()==False:
            print(f"Sorry,Please enter correct integer value")
        elif choice.isdigit()==True:
            if int(choice) in acceptable_range:
                within_range=True
            else:
                print(f"Number entered is out of range:")
                within_range=False
                
    return int(choice)

# %%
def game_on_choice():
    choice = 'Wrong'
    
    # Check if the choice is NOT in our list of valid answers
    while choice not in ['Y', 'N']:
        # .upper() converts inputs like 'y' to 'Y' automatically
        choice = input("Please enter your choice 'Y' or 'N': ").upper()
        
        if choice not in ['Y', 'N']:
            print("Invalid input, please enter correct input.")
            
    # Once the loop breaks (meaning they entered Y or N), return it
    if choice == 'Y':
        return True
    else:
        return False

# Test it:
# is_game_on = game_on_choice()

# %%
def enter_value():
    value=' '
    while value not in ['O','X']:
        print("invalid input, please enter either 'O' or 'X':")
        value=input(f"Enter either 'O' or 'X':")
    return value

# %%
def player_turn():
# Out:
#   Cell In[14], line 2
#
#     ^
# _IncompleteInputError: incomplete input

# %%
# Create a board with 10 empty spaces (we ignore index 0)
game_board = [' '] * 10 

# 1. Show the empty board
print("Welcome to Tic Tac Toe!")
display_board(game_board)

# 2. Ask the user where they want to play
position = user_choice()

# 3. Update the board with a marker at that position
game_board[position] = enter_value()

# 4. Show the updated board!
print("\nUpdated Board:")
display_board(game_board)
# Out:
# Welcome to Tic Tac Toe!
#    |   |
# -----------
#    |   |
# -----------
#    |   |
# Enter number from 1-9: 1
# invalid input, please enter either 'O' or 'X':
# Enter either 'O' or 'X': 0
# invalid input, please enter either 'O' or 'X':
# Enter either 'O' or 'X': O
# Updated Board:
#    |   |
# -----------
#    |   |
# -----------
#  O |   |

# %%
def check_win(board, mark):
    # Returns True if any of the 8 winning combinations are entirely filled by the given mark
    
    return (
        # Check Horizontal Rows
        (board[7] == mark and board[8] == mark and board[9] == mark) or # Top row
        (board[4] == mark and board[5] == mark and board[6] == mark) or # Middle row
        (board[1] == mark and board[2] == mark and board[3] == mark) or # Bottom row
        
        # Check Vertical Columns
        (board[7] == mark and board[4] == mark and board[1] == mark) or # Left column
        (board[8] == mark and board[5] == mark and board[2] == mark) or # Middle column
        (board[9] == mark and board[6] == mark and board[3] == mark) or # Right column
        
        # Check Diagonals
        (board[7] == mark and board[5] == mark and board[3] == mark) or # Diagonal 1
        (board[9] == mark and board[5] == mark and board[1] == mark)    # Diagonal 2
    )

# --- How to test it ---
# test_board = ['#', 'X', 'O', 'X', 'O', 'X', 'O', 'X', 'O', 'X']
# print(check_win(test_board, 'X'))  # This would return True (Diagonal win)

# %%
def space_check(board, position):
    # Returns True if the requested position is empty
    return board[position] == ' '

# %%
def full_board_check(board):
    # Loop through positions 1 to 9
    for i in range(1, 10):
        # If we find even one empty space, the board is NOT full
        if space_check(board, i):
            return False
            
    # If the loop finishes and finds no empty spaces, the board IS full
    return True

# %%
# 1. Get the player's choice
position = user_choice()

# 2. Check if the space is valid using a while loop
while not space_check(game_board, position):
    print("That space is already taken! Choose another.")
    position = user_choice()

# 3. Place the marker since we know the space is empty
game_board[position] = p1_marker
display_board(game_board)

# 4. Check for Win or Tie
if check_win(game_board, p1_marker):
    print("Player 1 wins!")
    game_is_running = False
elif full_board_check(game_board):
    print("It's a tie!")
    game_is_running = False
else:
    # Switch turns to Player 2...
    pass
# Out:
# Enter number from 1-9: 2
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 10
#       7     position = user_choice()
#       9 # 3. Place the marker since we know the space is empty
# ---> 10 game_board[position] = p1_marker
#      11 display_board(game_board)
#      13 # 4. Check for Win or Tie
#
# NameError: name 'p1_marker' is not defined

# %%
def play_game():
    print("Welcome to Tic Tac Toe!")
    
    # 1. The Outer Loop (Allows for multiple games)
    while True:
        
        # --- SETUP PHASE ---
        the_board = [' '] * 10
        
        # Get Player 1's marker using your function
        player1_marker = enter_value()
        
        # Automatically assign the opposite to Player 2
        if player1_marker == 'X':
            player2_marker = 'O'
        else:
            player2_marker = 'X'
            
        turn = 'Player 1'
        print(f"Player 1 will go first and play as {player1_marker}.")
        
        # Ask if they are ready using your function
        game_is_running = game_on_choice()

        # --- THE GAME LOOP ---
        while game_is_running:
            
            if turn == 'Player 1':
                # Player 1's Turn
                display_board(the_board)
                print("\nPlayer 1's turn:")
                position = user_choice()
                
                # Check if space is valid before placing
                while not space_check(the_board, position):
                    print("That space is already taken! Choose another.")
                    position = user_choice()
                    
                the_board[position] = player1_marker
                
                # Check for win or tie
                if check_win(the_board, player1_marker):
                    display_board(the_board)
                    print("Congratulations! Player 1 has won the game!")
                    game_is_running = False
                elif full_board_check(the_board):
                    display_board(the_board)
                    print("The game is a tie!")
                    game_is_running = False
                else:
                    turn = 'Player 2' # Switch turn
                    
            else:
                # Player 2's Turn
                display_board(the_board)
                print("\nPlayer 2's turn:")
                position = user_choice()
                
                # Check if space is valid before placing
                while not space_check(the_board, position):
                    print("That space is already taken! Choose another.")
                    position = user_choice()
                    
                the_board[position] = player2_marker
                
                # Check for win or tie
                if check_win(the_board, player2_marker):
                    display_board(the_board)
                    print("Congratulations! Player 2 has won the game!")
                    game_is_running = False
                elif full_board_check(the_board):
                    display_board(the_board)
                    print("The game is a tie!")
                    game_is_running = False
                else:
                    turn = 'Player 1' # Switch turn back
                    
        # --- REPLAY PHASE ---
        print("\nWould you like to play another round?")
        if not game_on_choice():
            print("Thanks for playing! Goodbye.")
            break # Breaks the outer loop and ends the program

# Start the game!
play_game()
# Out:
# Welcome to Tic Tac Toe!
# invalid input, please enter either 'O' or 'X':
# Enter either 'O' or 'X': O
# Player 1 will go first and play as O.
# Please enter your choice 'Y' or 'N':  Y
#    |   |
# -----------
#    |   |
# -----------
#    |   |
#
# Player 1's turn:
# Enter number from 1-9: O
# Sorry,Please enter correct integer value
# Enter number from 1-9: 1
#    |   |
# -----------
#    |   |
# -----------
#  O |   |
#
# Player 2's turn:
# Enter number from 1-9: 2
#    |   |
# -----------
#    |   |
# -----------
#  O | X |
#
# Player 1's turn:
# Enter number from 1-9: 3
#    |   |
# -----------
#    |   |
# -----------
#  O | X | O
#
# Player 2's turn:
# Enter number from 1-9: 5
#    |   |
# -----------
#    | X |
# -----------
#  O | X | O
#
# Player 1's turn:
# Enter number from 1-9: 4
#    |   |
# -----------
#  O | X |
# -----------
#  O | X | O
#
# Player 2's turn:
# Enter number from 1-9: 8
#    | X |
# -----------
#  O | X |
# -----------
#  O | X | O
# Congratulations! Player 2 has won the game!
#
# Would you like to play another round?
# Please enter your choice 'Y' or 'N':  N
# Thanks for playing! Goodbye.
